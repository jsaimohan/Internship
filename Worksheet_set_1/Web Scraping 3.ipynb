# %%
import pandas as pd
import re
import selenium 
from selenium import webdriver
from time import sleep
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys

# %%
#Question:1
driver=webdriver.Chrome('chromedriver.exe')
url='https://www.amazon.in/'
driver.get(url)
input_name=input()
time.sleep(5)
search_job=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search_job.send_keys(input_name)
search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div")
search_btn.click()
# Out:
# <ipython-input-236-82671f947698>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('chromedriver.exe')
# guitar
# <ipython-input-236-82671f947698>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
# <ipython-input-236-82671f947698>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div")

# %%
#Question:2,continuation for Que#1
# scraping all product urls
product_urls = []
start=0
end=3
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

#Make empty lists
Brand = []   
Name = []
Rating = []
no_of_ratings = []
Price = []
Return = []
expected_delivery = []
Availability = [] 
Other_Details = []

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Brand from xpath
    try:
        brand = driver.find_element_by_xpath('//a[@id="bylineInfo"]')      
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')    


    time.sleep(1)
    # Extracting name from id
    try:
        name = driver.find_element_by_id('productTitle')      
        Name.append(name.text)
    except NoSuchElementException:
        Name.append('-')


    time.sleep(1)    
    # Extracting Ratings from xpath    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    # Extracting No of Ratings from xpath
    try:
        no_rating = driver.find_element_by_id('acrCustomerReviewText')  
        no_of_ratings.append(no_rating.text)
    except NoSuchElementException:
        no_of_ratings.append('-')


    time.sleep(1)
    # Extracting price from xpath    
    try:
        price = driver.find_element_by_xpath('//td[@class="a-span12"]')  
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')


    time.sleep(1)
    # Extracting Return from xpath
    try:
        return_ = driver.find_element_by_xpath('//a[@class="a-size-small a-link-normal a-text-normal"]')  
        Return.append(return_.text)
    except NoSuchElementException:
        Return.append('-')


    time.sleep(1)
    # Extracting expected_delivery from xpath
    try:
        exptd_dlvry= driver.find_element_by_xpath('//span[@class="a-color-error"]')  
        expected_delivery.append(exptd_dlvry.text)
    except NoSuchElementException:
         expected_delivery.append('-')


    time.sleep(1)
    # Extracting Availability from xpath         
    try:
        avl= driver.find_element_by_xpath('//span[@class="a-size-medium a-color-success"]')  
        Availability.append(avl.text)
    except NoSuchElementException:
        Availability.append('-')



    time.sleep(1)
    # Extracting Other Details from xpath    
    try:
        othr_dtls= driver.find_element_by_xpath('//ul[@class="a-unordered-list a-vertical a-spacing-mini"]')  
        Other_Details.append(othr_dtls.text)
    except NoSuchElementException:
        Other_Details.append('-')

time.sleep(2)    
# Make dataframe
df = pd.DataFrame({'Brand':Brand,'Name':Name,'Rating':Rating,'No. of ratings':no_of_ratings,'Price':Price,
                        'Return/Exchange':Return,'Expected Delivery':expected_delivery,'Availability':Availability,
                        'Other Details':Other_Details,'URL':product_urls})
df
# Out:
# <ipython-input-239-c6c35093b067>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
# <ipython-input-239-c6c35093b067>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nxt_button=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")     #scraping the list of buttons from the page
# <ipython-input-239-c6c35093b067>:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brand = driver.find_element_by_xpath('//a[@id="bylineInfo"]')
# <ipython-input-239-c6c35093b067>:39: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_id('productTitle')
# ...

# %%
#Question=3

driver= webdriver.Chrome("chromedriver.exe")
url='https://images.google.com/'
driver.get(url)

Fruit=[]
Cars=[]
ML=[]
Guitar=[]
Cakes=[]
Keywords =['Fruits','Cars','Machine Learning','Guitar','Cakes']
for i in Keywords:
    driver.get(url)
    sleep(5)
    search_image=driver.find_element_by_xpath('//input[@type="text"]')
    search_btn=driver.find_element_by_xpath('//button[@class="Tg7LZd"]')
    search_image.send_keys(i)
    search_btn.click()
    sleep(4)
    
    fruit_image=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
    for i in fruit_image:
        Fruit.append(i.get_attribute('src'))
    sleep(2)
    
    car_image=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
    for i in fruit_image:
        Cars.append(i.get_attribute('src'))
    sleep(2)
    
    ml_image=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
    for i in fruit_image:
        ML.append(i.get_attribute('src'))
    sleep(2)
    
    guitar=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
    for i in fruit_image:
        Guitar.append(i.get_attribute('src'))
    cake=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
    for i in fruit_image:
        Cakes.append(i.get_attribute('src'))
print(len(Fruit_image),len(Cars_image),len(ML_image),len(Guitar),len(Cakes))

Images=pd.DataFrame({'Fruit':Fruit[0:10],'Cars':Cars[0:10],'ML':ML[0:10],'Guitar':Guitar[0:10],'Cakes':Cakes[0:10]})
Images
# Out:
# <ipython-input-45-6358806ff316>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome("chromedriver.exe")
# <ipython-input-45-6358806ff316>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_image=driver.find_element_by_xpath('//input[@type="text"]')
# <ipython-input-45-6358806ff316>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath('//button[@class="Tg7LZd"]')
# <ipython-input-45-6358806ff316>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   fruit_image=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']/img")
# <ipython-input-45-6358806ff316>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ...

# %%
#Question=4

url = 'https://www.flipkart.com/'
driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)
sleep(2)
exit_btn=driver.find_element_by_xpath("/html/body/div[2]/div/div/button")
exit_btn.click()
sleep(2)
search_job= driver.find_element_by_class_name("_3704LK")
search_job.send_keys('Oneplus Nord, pixel 4A')
search_btn=driver.find_element_by_class_name("L0Z3Pu")
search_btn.click()
sleep(2)
Url=[]
url = driver.find_elements_by_xpath('//a[@class ="_1fQZEK"]')
for i in url:
    Url.append(i.get_attribute('href'))
Brand_name =[]
Price=[]
Colour=[]
Display_size=[]
Display_resolution=[]
Primary_Camera=[]
Secondary_camera=[]
RAM=[]
ROM= []
Battery_capacity =[]
Processor =[]
Processor_core =[]

for i in Url:
    driver.get(i)
    sleep(2)
    
    readmore =driver.find_element_by_xpath('//button[@class ="_2KpZ6l _1FH0tX"]')
    readmore.click()
    sleep(2)

    try:
        brand = driver.find_element_by_xpath('//span[@class="B_NuCI"]')
        Brand_name.append(brand.text)
        
    except:
        Brand_name.append('--') 
    
    
    try:
        price = driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(price.text)
        
    except:
        Price.append('--')
        
    try:
        color = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        Colour.append(color.text)
        
    except:
        Colour.append('--')
        
    try:
        dsize = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][2]/table/tbody/tr[1]/td[2]/ul/li')
        Display_size.append(dsize.text)
        
    except:
        Display_size.append('--')
        
        
    try:
        resolution = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][2]/table/tbody/tr[2]/td[2]/ul/li')
        Display_resolution.append(resolution.text)
        
    except:
        Display_resolution.append('--')
        
        
    try:
        pcamera = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]/ul/li')
        Primary_Camera.append(pcamera.text)
        
    except:
        Primary_Camera.append('--')
        
        
    try:
        scamera = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][5]/table/tbody/tr[5]/td[2]/ul/li')
        Secondary_camera.append(scamera.text)
        
    except:
        Secondary_camera.append('--')
        
        
    try:
        ram = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][4]/table/tbody/tr[2]/td[2]/ul/li')
        RAM.append(ram.text)
        
    except:
        RAM.append('--')
        
        
        
    try:
        rom = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        ROM.append(rom.text)
        
    except:
        ROM.append('--')
        
        
        
    try:
        battery = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][10]/table/tbody/tr[1]/td[2]/ul/li')
        Battery_capacity.append(battery.text)
        
    except:
        Battery_capacity.append('--')
        
        
    try:
        processor = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][3]/table/tbody/tr[2]/td[2]/ul/li')
        Processor.append(processor.text)
        
    except:
        Processor.append('--')
        
        
        
    try:
        core = driver.find_element_by_xpath('//div [@class ="_3k-BhJ"][3]/table/tbody/tr[3]/td[2]/ul/li')
        Processor_core.append(core.text)
        
    except:
        Processor_core.append('--')
Smartphone = pd.DataFrame({})

Smartphone['Brand_name / Mobile name'] =Brand_name
Smartphone['Price'] =Price
Smartphone['Colour'] =Colour
Smartphone['Display_size'] =Display_size
Smartphone['Display_resolution'] =Display_resolution
Smartphone['Primary_Camera'] =Primary_Camera
Smartphone['Secondary_camera'] =Secondary_camera
Smartphone['RAM'] =RAM
Smartphone['ROM'] =ROM
Smartphone['Battery_capacity'] =Battery_capacity 
Smartphone['Processor'] =Processor 
Smartphone['Processor_core'] =Processor_core 
Smartphone['Product URL'] = Url

Smartphone
# Out:
# <ipython-input-54-4b161bf45a2f>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# <ipython-input-54-4b161bf45a2f>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   exit_btn=driver.find_element_by_xpath("/html/body/div[2]/div/div/button")
# <ipython-input-54-4b161bf45a2f>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_job= driver.find_element_by_class_name("_3704LK")
# <ipython-input-54-4b161bf45a2f>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_class_name("L0Z3Pu")
# <ipython-input-54-4b161bf45a2f>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url = driver.find_elements_by_xpath('//a[@class ="_1fQZEK"]')
# ...

# %%
#Question=5
#importing regex
import re

driver = webdriver.Chrome('chromedriver.exe')
url='https://www.google.com/maps/'

driver.get(url)
sleep(2)
search = driver.find_element_by_xpath('//input[@class="tactile-searchbox-input"]')
search.send_keys('Hyderabad')

search_btn = driver.find_element_by_xpath('//button[@class="nhb85d-BIqFsb"]')
search_btn.click()
time.sleep(3)

link = driver.current_url
print("Current URL:",link)
latt = re.findall('\@(-?[\d\.]*)',link)
long = re.findall('\@[-?\d\.]*\,([-?\d\.]*)', link)

print("The Geospatial cordinates of location searched is: Lattitude: {},Longitude:{} ".format(latt,long))
# Out:
# <ipython-input-217-17b4db6eaa3e>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# <ipython-input-217-17b4db6eaa3e>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_xpath('//input[@class="tactile-searchbox-input"]')
# <ipython-input-217-17b4db6eaa3e>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_xpath('//button[@class="nhb85d-BIqFsb"]')
# Current URL: https://www.google.com/maps/place/Hyderabad,+Telangana/@17.4128084,78.1278536,10z/data=!3m1!4b1!4m5!3m4!1s0x3bcb99daeaebd2c7:0xae93b78392bafbc2!8m2!3d17.385044!4d78.486671
# The Geospatial cordinates of location searched is: Lattitude: ['17.4128084'],Longitude:['78.1278536']

# %%
#Question=6
driver = webdriver.Chrome('chromedriver.exe')
#Taking direct URL link to fundings tab since i am getting ads in betweeen  
url='https://trak.in/india-startup-funding-investment-2015/'
driver.get(url)
driver.maximize_window()
sleep(2)


Date =[]
Startup_name =[]
Industry_vertical =[]
Sub_vertical =[]
City_location=[]
Investers_name=[]
Investment_type =[]
Amount =[]



datejan =driver.find_elements_by_xpath('//div[@id ="tablepress-54_wrapper"]/div[3]/div[2]/table/tbody/tr//td[2]')
datefeb =driver.find_elements_by_xpath('//div[@id ="tablepress-55_wrapper"]/div[3]/div[2]/table/tbody/tr//td[2]')
datemar =driver.find_elements_by_xpath('//div[@id ="tablepress-56_wrapper"]/div[3]/div[2]/table/tbody/tr//td[2]')

for i in [datejan,datefeb,datemar]:
    try:
        for j in i:
            Date.append(j.text)
    except:
        Date.append('--')

startupjan =driver.find_elements_by_xpath('//div[@id ="tablepress-54_wrapper"]/div[3]/div[2]/table/tbody/tr//td[3]')
startupfeb =driver.find_elements_by_xpath('//div[@id ="tablepress-55_wrapper"]/div[3]/div[2]/table/tbody/tr//td[3]')
startupmar =driver.find_elements_by_xpath('//div[@id ="tablepress-56_wrapper"]/div[3]/div[2]/table/tbody/tr//td[3]')

for i in [startupjan,startupfeb,startupmar]:
    try:
        for j in i:
            Startup_name.append(j.text)
    except:
        Startup_name.append('--')

Industryjan =driver.find_elements_by_xpath('//div[@id ="tablepress-54_wrapper"]/div[3]/div[2]/table/tbody/tr//td[4]')
Industryfeb =driver.find_elements_by_xpath('//div[@id ="tablepress-55_wrapper"]/div[3]/div[2]/table/tbody/tr//td[4]')
Industrymar =driver.find_elements_by_xpath('//div[@id ="tablepress-56_wrapper"]/div[3]/div[2]/table/tbody/tr//td[4]')

for i in [Industryjan,Industryfeb,Industrymar]:
    try:
        for j in i:
            Industry_vertical.append(j.text)
    except:
        Industry_vertical.append('--')

Sub_verticaljan =driver.find_elements_by_xpath('//div[@id ="tablepress-54_wrapper"]/div[3]/div[2]/table/tbody/tr//td[5]')
Sub_verticalfeb =driver.find_elements_by_xpath('//div[@id ="tablepress-55_wrapper"]/div[3]/div[2]/table/tbody/tr//td[5]')
Sub_verticalmar =driver.find_elements_by_xpath('//div[@id ="tablepress-56_wrapper"]/div[3]/div[2]/table/tbody/tr//td[5]')

for i in [Sub_verticaljan,Sub_verticalfeb,Sub_verticalmar]:
    try:
        for j in i:
            Sub_vertical.append(j.text)
    except:
        Sub_vertical.append('--')

Cityjan =driver.find_elements_by_xpath('//div[@id ="tablepress-54_wrapper"]/div[3]/div[2]/table/tbody/tr//td[6]')
Cityfeb =driver.find_elements_by_xpath('//div[@id ="tablepress-55_wrapper"]/div[3]/div[2]/table/tbody/tr//td[6]')
Citymar =driver.find_elements_by_xpath('//div[@id ="tablepress-56_wrapper"]/div[3]/div[2]/table/tbody/tr//td[6]')

for i in [Cityjan,Cityfeb,Citymar]:
    try:
        for j in i:
            City_location.append(j.text)
    except:
        City_location.append('--')

Investersjan =driver.find_elements_by_xpath('//div[@id ="tablepress-54_wrapper"]/div[3]/div[2]/table/tbody/tr//td[7]')
Investersfeb =driver.find_elements_by_xpath('//div[@id ="tablepress-55_wrapper"]/div[3]/div[2]/table/tbody/tr//td[7]')
Investersmar =driver.find_elements_by_xpath('//div[@id ="tablepress-56_wrapper"]/div[3]/div[2]/table/tbody/tr//td[7]')

for i in [Investersjan,Investersfeb,Investersmar]:
    try:
        for j in i:
            Investers_name.append(j.text)
    except:
        Investers_name.append('--')

Iv_typejan =driver.find_elements_by_xpath('//div[@id ="tablepress-54_wrapper"]/div[3]/div[2]/table/tbody/tr//td[8]')
Iv_typefeb =driver.find_elements_by_xpath('//div[@id ="tablepress-55_wrapper"]/div[3]/div[2]/table/tbody/tr//td[8]')
Iv_typemar =driver.find_elements_by_xpath('//div[@id ="tablepress-56_wrapper"]/div[3]/div[2]/table/tbody/tr//td[8]')

for i in [Iv_typejan,Iv_typefeb,Iv_typemar]:
    try:
        for j in i:
            Investment_type.append(j.text)
    except:
        Investment_type.append('--')

Amountjan =driver.find_elements_by_xpath('//div[@id ="tablepress-54_wrapper"]/div[3]/div[2]/table/tbody/tr//td[9]')
Amountfeb =driver.find_elements_by_xpath('//div[@id ="tablepress-55_wrapper"]/div[3]/div[2]/table/tbody/tr//td[9]')
Amountmar =driver.find_elements_by_xpath('//div[@id ="tablepress-56_wrapper"]/div[3]/div[2]/table/tbody/tr//td[9]')

for i in [Amountjan,Amountfeb,Amountmar]:
    try:
        for j in i:
            Amount.append(j.text)
    except:
        Amount.append('--')
        
print(len(Date),len(Startup_name),len(Industry_vertical),len(Sub_vertical),len(City_location),len(Investers_name),len(Investment_type),len(Amount))

funding_deals =pd.DataFrame({})

funding_deals ['Date'] = Date
funding_deals ['Startup_name'] = Startup_name 
funding_deals ['Industry / vertical'] = Industry_vertical 
funding_deals ['Sub_vertical'] = Sub_vertical 
funding_deals ['City / location'] = City_location
funding_deals ["Investers'name"] = Investers_name
funding_deals ['Investment_type'] = Investment_type 
funding_deals ['Amount in(USD)'] = Amount

funding_deals
# Out:
# <ipython-input-97-7baeae90638b>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# <ipython-input-97-7baeae90638b>:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   datejan =driver.find_elements_by_xpath('//div[@id ="tablepress-54_wrapper"]/div[3]/div[2]/table/tbody/tr//td[2]')
# <ipython-input-97-7baeae90638b>:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   datefeb =driver.find_elements_by_xpath('//div[@id ="tablepress-55_wrapper"]/div[3]/div[2]/table/tbody/tr//td[2]')
# <ipython-input-97-7baeae90638b>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   datemar =driver.find_elements_by_xpath('//div[@id ="tablepress-56_wrapper"]/div[3]/div[2]/table/tbody/tr//td[2]')
# ...

# %%
#Question:7
driver= webdriver.Chrome("chromedriver.exe")
url="https://www.digit.in/"
driver.get(url)
driver.maximize_window()
sleep(2)
Laptop_btn=driver.find_element_by_xpath("/html/body/div[4]/div/div[2]/div[2]/div[4]/ul/li[9]/a")
Laptop_btn.click()
sleep(3)
# Out:
# <ipython-input-221-92533ca3deda>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome("chromedriver.exe")
# <ipython-input-221-92533ca3deda>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   Laptop_btn=driver.find_element_by_xpath("/html/body/div[4]/div/div[2]/div[2]/div[4]/ul/li[9]/a")

# %%
#Question:7
Name=[]
OS=[]
Display=[]
Processor=[]
Memory=[]
Weight=[]
Dimension=[]
Graphic_pr = []
Price=[]

#scraping the individual data from the link available
try:
    for i in driver.find_elements_by_xpath('//h3'):  
        Name.append(i.text)
except:
    Name.append('-')
    
for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]'):
    OS.append(i.text)

for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]'):
    Display.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]'):
    Processor.append(i.text)

for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]'):
    Memory.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]'):
    Weight.append(i.text)

for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]'):
    Dimension.append(i.text)

for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[9]/td[3]'):
    Graphic_pr.append(i.text)

for i in driver.find_elements_by_xpath('//td[@class="smprice"]'):
    Price.append(i.text.split(' ')[1])
    
    
#checking the length of all data scraped
len(Name),len(OS),len(Display), len(Processor), len(Memory), len(Weight), len(Dimension), len(Graphic_pr), len(Price)

df= pd.DataFrame({'Name':Name, 'OS':OS, 'Display':Display, 'Processor':Processor, 'Memory':Memory, 'Weight':Weight, 'Dimension':Dimension, 'Graphic Processor':Graphic_pr, 'Price':Price})
df
# Out:
# <ipython-input-223-369732740fa7>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//h3'):
# <ipython-input-223-369732740fa7>:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]'):
# <ipython-input-223-369732740fa7>:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]'):
# <ipython-input-223-369732740fa7>:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]'):
# ...

# %%
#Question=8

driver= webdriver.Chrome("chromedriver.exe")
url='https://www.forbes.com/billionaires/'
driver.get(url)
driver.maximize_window()

Rank=[]
Name=[]
Net_worth=[]
Age=[]
Citizenship=[]
Source=[]
Industry =[]
for i in range(14):
    print('Scraping Page',i+1)
    
    rank=driver.find_elements_by_xpath("//div[@class='rank']")
    for r in rank:
        Rank.append(r.text)  
    sleep(1) 
    
    name=driver.find_elements_by_xpath("//div[@class='personName']")
    for n in name:
        Name.append(n.text)
    sleep(1)
    
    net_worth=driver.find_elements_by_xpath("//div[@class='netWorth']")
    for nw in net_worth:
        Net_worth.append(nw.text)
    sleep(1)
    
    age=driver.find_elements_by_xpath("//div[@class='age']")
    for a in age:
        Age.append(a.text)
    sleep(1)
        
    citizenship=driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for c in citizenship:
        Citizenship.append(c.text)
    sleep(1)
        
    source=driver.find_elements_by_xpath("//div[@class='source-column']")
    for s in source:
        Source.append(s.text)
    sleep(1)
        
    industry=driver.find_elements_by_xpath("//div[@class='category']")
    for i in industry:
        Industry.append(i.text)
    sleep(1)
    try:
        Next_btn=driver.find_element_by_xpath("//div[@class='next-page']")
        Next_btn.click()
        sleep(2)
    except:
        break  

Billionaires=pd.DataFrame({})
Billionaires['Rank']=Rank
Billionaires['Name']= Name
Billionaires['Net_worth']=Net_worth
Billionaires['Age']=Age
Billionaires['Citizenship']=Citizenship
Billionaires['Source']=Source
Billionaires['Industry']=Industry
Billionaires
# Out:
# <ipython-input-139-72532d6e9a0e>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome("chromedriver.exe")
# Scraping Page 1
# <ipython-input-139-72532d6e9a0e>:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rank=driver.find_elements_by_xpath("//div[@class='rank']")
# <ipython-input-139-72532d6e9a0e>:23: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name=driver.find_elements_by_xpath("//div[@class='personName']")
# <ipython-input-139-72532d6e9a0e>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   net_worth=driver.find_elements_by_xpath("//div[@class='netWorth']")
# <ipython-input-139-72532d6e9a0e>:33: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ...

# %%
#question-9
driver= webdriver.Chrome("chromedriver.exe")
url="https://www.youtube.com/watch?v=AZGcmvrTX9M"
driver.get(url)
driver.maximize_window()
sleep(4)
# Out:
# <ipython-input-224-b7cb90241969>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome("chromedriver.exe")

# %%
#question-9
Comments=[]
Upvotes=[]
Date=[]

# Extracting the elements of usernames and comments.
try:
    for _ in range(500):
        driver.execute_script("window.scrollBy(0,500)")
    
         
        comment_elems = driver.find_elements_by_xpath('//*[@id="content-text"]')
        for i in comment_elems:
            if(len(Comments)<500):
                Comments.append(i.text)

            
        up_vote =  driver.find_elements_by_xpath('//*[@id="vote-count-middle"]') 
        for i in up_vote:
            if(len(Upvotes)<500):
                Upvotes.append(i.text)
            
        date = driver.find_elements_by_xpath("//*[@id='author-reputation']")
        for i in date:
            if(len(Date)<500):
                Date.append(i.text)
        
        
            
except exceptions.NoSuchElementException:
        print('No output')
# Out:
# <ipython-input-225-e17e7479dc9b>:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   comment_elems = driver.find_elements_by_xpath('//*[@id="content-text"]')
# <ipython-input-225-e17e7479dc9b>:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   up_vote =  driver.find_elements_by_xpath('//*[@id="vote-count-middle"]')
# <ipython-input-225-e17e7479dc9b>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   date = driver.find_elements_by_xpath("//*[@id='author-reputation']")

# %%
#Question:9 
print(len(Comments), len(Upvotes), len(Date))
df= pd.DataFrame({'Comments':Comments,'Upvotes': Upvotes, 'Date':Date})
df
# Out:
# 500 500 500
#                                               Comments Upvotes Date
# 0    Tenet is Awesome, can't wait for Dunkirk and I...    8.7K
# 1    To understand Tenet you need to watch it at le...    2.6K
# 2    Christopher Nolan knows so much about time tha...    1.7K
# 3    Those aren’t dislikes. They’re likes.... but t...    4.2K
# 4    Christopher Nolan is so ahead of his time that...      5K
# ..                                                 ...     ...  ...
# 495  That was one of the best movies I have ever se...      62
# 496  This movie is a masterpiece. You have to see m...      1K
# 497  Other directors: No spoilers in my trailer!\nC...      35
# 498  Robert Pattinson is going to be in the big lea...    2.9K
# 499  0:00:00 Rainy Night in Tallinn\n0:08:01 Windmi...       2
#
# [500 rows x 3 columns]

# %%
#Question=10
driver=webdriver.Chrome("chromedriver.exe")
url="https://www.hostelworld.com/"
driver.get(url)
driver.maximize_window()
sleep(2)
search_hotel=driver.find_element_by_xpath("//input[@id='location-text-input-field']")
search_hotel.click()
sleep(2)
search_hotel1=driver.find_element_by_xpath("//input[@id='search-input-field']")
search_hotel1.send_keys('London')
sleep(2)
search_btn1=driver.find_element_by_xpath("//div[@class='label']")
search_btn1.click()
sleep(2)
search_btn=driver.find_element_by_xpath("//button[@id='search-button']")
search_btn.click()
sleep(2)
# Out:
# <ipython-input-182-da13fee4925a>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# <ipython-input-182-da13fee4925a>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_hotel=driver.find_element_by_xpath("//input[@id='location-text-input-field']")
# <ipython-input-182-da13fee4925a>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_hotel1=driver.find_element_by_xpath("//input[@id='search-input-field']")
# <ipython-input-182-da13fee4925a>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn1=driver.find_element_by_xpath("//div[@class='label']")
# <ipython-input-182-da13fee4925a>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
#Question=10

Hotel_Name=[]
Dist_from_city=[]
Total_reviews=[]
Overall_reviews=[]
Facility=[]
Page_url=[]


for i in range(3):
    print('Scraping Page',i+1)
    
    hotel_name=driver.find_elements_by_xpath("//h2[@class='title title-6']")
    for h in hotel_name:
        Hotel_Name.append(h.text)
        
    page_url=driver.find_elements_by_xpath("//h2[@class='title title-6']/a")
    for r in page_url:
        Page_url.append(r.get_attribute('href'))
    
    dist_from_city=driver.find_elements_by_xpath("//span[@class='description']")
    for dist in dist_from_city:
        Dist_from_city.append(dist.text)
    
    total_reviews=driver.find_elements_by_xpath("//div[@class='reviews']")
    for t in total_reviews:
        Total_reviews.append(t.text.replace('Total Reviews','').strip())
        
    overall_reviews=driver.find_elements_by_xpath("//div[@class='keyword']")
    for t in overall_reviews:
        Overall_reviews.append(t.text)
        
  
    facility=driver.find_elements_by_xpath("//div[@class='facilities-label facilities']")
    for t in facility:
        Facility.append(t.text.replace('\n','--'))
    try:
        Next_btn=driver.find_element_by_xpath("//div[@class='pagination-item pagination-next']")
        Next_btn.click() 
        sleep(2)
    except:
        break 
        
Ratings=[]
Property_desc=[]
for i in Page_url:
    driver.get(i)
    sleep(2)
    try:
        property_desc=driver.find_element_by_xpath("//div[@class='content collapse-content']")
        Property_desc.append(property_desc.text)
    except:
        Property_desc.append('--')
    
    try:
        rating=driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
        Ratings.append(rating.text)
    except:
        Ratings.append('--')
        
print(len(Hotel_Name),len(Dist_from_city),len(Total_reviews),len(Overall_reviews),len(Facility),len(Ratings),len(Property_desc))

Hotel_detail=pd.DataFrame({})
Hotel_detail['Hotel_Name']= Hotel_Name
Hotel_detail['Dist_from_city']=Dist_from_city
Hotel_detail['Total_reviews']=Total_reviews
Hotel_detail['Overall_reviews']=Overall_reviews[1:]
Hotel_detail['Facility']=Facility
Hotel_detail['Property_desc']=Property_desc
Hotel_detail['Ratings']=Ratings
Hotel_detail
# Out:
# Scraping Page 1
# <ipython-input-183-c3fc6288f614>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   hotel_name=driver.find_elements_by_xpath("//h2[@class='title title-6']")
# <ipython-input-183-c3fc6288f614>:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   page_url=driver.find_elements_by_xpath("//h2[@class='title title-6']/a")
# <ipython-input-183-c3fc6288f614>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dist_from_city=driver.find_elements_by_xpath("//span[@class='description']")
# <ipython-input-183-c3fc6288f614>:26: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   total_reviews=driver.find_elements_by_xpath("//div[@class='reviews']")
# ...
