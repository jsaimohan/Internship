# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing dataset and Checking First five rows 
data = pd.read_csv("customer_retention_dataset1.csv")
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
# checking data shape
data.shape
# Out:
# (269, 71)

# %%
#checking for missing values
data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
#data cleaning
data.columns = data.columns.str.replace(' ','')

# %%
data.columns = data.columns.str.replace('\t','')

# %%
data.columns = data.columns.str.replace('�','')

# %%
data.columns
# Out:
# Index(['1Genderofrespondent', '2Howoldareyou?',
#        '3Whichcitydoyoushoponlinefrom?',
#        '4WhatisthePinCodeofwhereyoushoponlinefrom?',
#        '5SinceHowLongYouareShoppingOnline?',
#        '6Howmanytimesyouhavemadeanonlinepurchaseinthepast1year?',
#        '7Howdoyouaccesstheinternetwhileshoppingon-line?',
#        '8Whichdevicedoyouusetoaccesstheonlineshopping?',
#        '9Whatisthescreensizeofyourmobiledevice?',
#        '10Whatistheoperatingsystem(OS)ofyourdevice?',
#        '11Whatbrowserdoyourunonyourdevicetoaccessthewebsite?',
#        '12Whichchanneldidyoufollowtoarriveatyourfavoriteonlinestoreforthefirsttime?',
#        '13Afterfirstvisit,howdoyoureachtheonlineretailstore?',
#        '14Howmuchtimedoyouexplorethee-retailstorebeforemakingapurchasedecision?',
#        '15WhatisyourpreferredpaymentOption?',
#        '16Howfrequentlydoyouabandon(selectinganitemsandleavingwithoutmakingpayment)yourshoppingcart?',
#        '17WhydidyouabandontheBag,ShoppingCart?',
# ...

# %%
fm=data.to_csv("fm.csv")

# %%
# Analysis regarding city 
plt.figure(figsize = (20,6))
sns.countplot(x = '3Whichcitydoyoushoponlinefrom?', data = data)
plt.title('Analysis of Customer according to city')
plt.xlabel('City')
plt.show()

# %%
fig = px.pie(data, names='3Whichcitydoyoushoponlinefrom?', title='City of the customer')
fig.show()
# Out:
# <div>                            <div id="84f88ef6-fa21-42e3-bda9-05dae0f6e79b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84f88ef6-fa21-42e3-bda9-05dae0f6e79b")) {                    Plotly.newPlot(                        "84f88ef6-fa21-42e3-bda9-05dae0f6e79b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"3Whichcitydoyoushoponlinefrom?=%{label}<extra></extra>","labels":["Delhi","Delhi","Greater Noida","Karnal ","Bangalore ","Noida","Delhi","Delhi","Solan","Delhi","Moradabad","Noida","Gurgaon ","Greater Noida","Karnal ","Bangalore ","Noida","Delhi","Delhi","Solan","Noida","Gurgaon ","Greater Noida","Greater Noida","Merrut","Bangalore ","Ghaziabad","Delhi","Greater Noida","Karnal ","Bangalore ","Noida","Delhi"
# ...

# %%
#More number of customers visiting from:
#1.Delhi 2. Greater Noida 3. Noida 4.Banglore 5. Karnal

# %%
#anaylsis by gender based
plt.figure(figsize = (8,6))
sns.countplot(x = '1Genderofrespondent', data = data, palette=['r', 'b'])
plt.title('Analysis of Customers by Gender')
plt.show()
fig = px.pie(data, names='1Genderofrespondent', title='Gender')
fig.show()
# Out:
# <div>                            <div id="f4ff95a0-8d2c-441d-b412-b8a44b7606b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4ff95a0-8d2c-441d-b412-b8a44b7606b4")) {                    Plotly.newPlot(                        "f4ff95a0-8d2c-441d-b412-b8a44b7606b4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"1Genderofrespondent=%{label}<extra></extra>","labels":["Male","Female","Female","Male","Female","Female","Male","Male","Female","Female","Male","Female","Female","Female","Female","Female","Male","Male","Female","Female","Female","Male","Male","Female","Female","Female","Male","Male","Female","Female","Female","Male","Male","Female","Female","Female","Male","Male","Female","Female","Female","Male","Male","F
# ...

# %%
#Above plots shows that customers who are visiting, close to 67 %, are females

# %%
#analysis by old or new customers
plt.figure(figsize = (20,6))
sns.countplot(x = '5SinceHowLongYouareShoppingOnline?',hue = '1Genderofrespondent' ,data = data)
plt.title('Customer Analysis as old/New customers')
plt.xlabel('City')
plt.show()


fig = px.pie(data, names='5SinceHowLongYouareShoppingOnline?', title='Old/new customers')
fig.show()
# Out:
# <div>                            <div id="3284dd4f-ed89-4172-9293-dbf3e766f0d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3284dd4f-ed89-4172-9293-dbf3e766f0d7")) {                    Plotly.newPlot(                        "3284dd4f-ed89-4172-9293-dbf3e766f0d7",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"5SinceHowLongYouareShoppingOnline?=%{label}<extra></extra>","labels":["Above 4 years","Above 4 years","3-4 years","3-4 years","2-3 years","Above 4 years","Above 4 years","3-4 years","2-3 years","Less than 1 year","Above 4 years","Above 4 years","2-3 years","Above 4 years","Less than 1 year","2-3 years","1-2 years","Less than 1 year","1-2 years","1-2 years","1-2 years","3-4 years","Above 4 years","Above 4 ye
# ...

# %%
#Most of the online shoppers have more than 5 years experience(36.4%)

# %%
data.groupby(['3Whichcitydoyoushoponlinefrom?', '4WhatisthePinCodeofwhereyoushoponlinefrom?']).size()
# Out:
# 3Whichcitydoyoushoponlinefrom?  4WhatisthePinCodeofwhereyoushoponlinefrom?
# Bangalore                       530068                                         5
#                                 560001                                         1
#                                 560002                                         4
#                                 560003                                         4
#                                 560010                                         8
#                                 560013                                         3
#                                 560018                                         4
#                                 560037                                         8
# Bulandshahr                     203001                                         2
# Delhi                           110008                                         7
#                                 110009                                         4
# ...

# %%
#1.We can see in Bangalore there is even distrubution of pincodes except for two codes, which are little more used than the others.
#2.Bulandshahr,Solan,Merrut,Moradabad, being smaller cities have 1 or 2 pincodes.
#3.Delhi also has good # of pincodes except 1 code(110044) which is used by more than 25 % of customers.
#4.In Greater Noida also more than 80% of times cutomers are from (201308 ,201310) pin codes .
#5. In Karnal city, second highest orders are placed on 132001 pincode
#6. In Noida also 70% of customers are using 201308.
#7. In above analysis it can be predicted that in metro cities there are few regions where a company can have more delivery focus
#Above plot shows that there are very large number of People who are doing online shopping from the past 1 to 2 years.

# %%
data.value_counts(data['6Howmanytimesyouhavemadeanonlinepurchaseinthepast1year?'])
# Out:
# 6Howmanytimesyouhavemadeanonlinepurchaseinthepast1year?
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# dtype: int64

# %%
plt.figure(figsize = (18,6))
sns.countplot(x ='6Howmanytimesyouhavemadeanonlinepurchaseinthepast1year?', data = data)
plt.title('Customers Online Purchace Frequency')
plt.show()

fig = px.pie(data, names='6Howmanytimesyouhavemadeanonlinepurchaseinthepast1year?', title='Purchase Frequency in past year')
fig.show()
# Out:
# <div>                            <div id="cc0c0089-1251-43f2-b14e-64177794c4d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc0c0089-1251-43f2-b14e-64177794c4d1")) {                    Plotly.newPlot(                        "cc0c0089-1251-43f2-b14e-64177794c4d1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"6Howmanytimesyouhavemadeanonlinepurchaseinthepast1year?=%{label}<extra></extra>","labels":["31-40 times","41 times and above","41 times and above","Less than 10 times","11-20 times","41 times and above","31-40 times","Less than 10 times","Less than 10 times","Less than 10 times","21-30 times","Less than 10 times","Less than 10 times","11-20 times","41 times and above","41 times and above","21-30 times","Les
# ...

# %%
#In the past 1 year, customers who have purchased online, less than 10 times are of 42.4% and also 23.4% Customers Purchased 31-40 times

# %%
#Analysis of type of internet used for online shopping:
data.value_counts(data['7Howdoyouaccesstheinternetwhileshoppingon-line?'])
# Out:
# 7Howdoyouaccesstheinternetwhileshoppingon-line?
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# dtype: int64

# %%
#replacing both mobile internet count in to one
data['7Howdoyouaccesstheinternetwhileshoppingon-line?']= data['7Howdoyouaccesstheinternetwhileshoppingon-line?'].replace('Mobile internet','Mobile Internet')
data.value_counts(data['7Howdoyouaccesstheinternetwhileshoppingon-line?'])
# Out:
# 7Howdoyouaccesstheinternetwhileshoppingon-line?
# Mobile Internet    189
# Wi-Fi               76
# Dial-up              4
# dtype: int64

# %%
plt.figure(figsize = (18,6))
sns.countplot(x ='7Howdoyouaccesstheinternetwhileshoppingon-line?', data = data)
plt.title('Analysis of Customer according Internet used')
plt.show()

fig = px.pie(data, names='7Howdoyouaccesstheinternetwhileshoppingon-line?', title='Internet type used for online shopping')
fig.show()
# Out:
# <div>                            <div id="35d30dc7-9561-4a01-a7ab-67837ef828b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35d30dc7-9561-4a01-a7ab-67837ef828b2")) {                    Plotly.newPlot(                        "35d30dc7-9561-4a01-a7ab-67837ef828b2",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"7Howdoyouaccesstheinternetwhileshoppingon-line?=%{label}<extra></extra>","labels":["Dial-up","Wi-Fi","Mobile Internet","Mobile Internet","Wi-Fi","Wi-Fi","Wi-Fi","Mobile Internet","Wi-Fi","Wi-Fi","Mobile Internet","Wi-Fi","Wi-Fi","Wi-Fi","Wi-Fi","Mobile Internet","Mobile Internet","Wi-Fi","Wi-Fi","Wi-Fi","Wi-Fi","Wi-Fi","Mobile Internet","Mobile Internet","Mobile Internet","Mobile Internet","Mobile Internet"
# ...

# %%
#Nearly 70% of customers use mobile internet for online shopping.

# %%
#Analysis of customers devise usage for online shopping:
plt.figure(figsize = (18,6))
sns.countplot(x ='8Whichdevicedoyouusetoaccesstheonlineshopping?', data = data)
plt.title('Analysis of Customer according device used ')
plt.show()
fig = px.pie(data, names='8Whichdevicedoyouusetoaccesstheonlineshopping?', title='Device used for shopping')
fig.show()
# Out:
# <div>                            <div id="f8ebcbe1-e930-455e-a10a-aac983bb9503" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8ebcbe1-e930-455e-a10a-aac983bb9503")) {                    Plotly.newPlot(                        "f8ebcbe1-e930-455e-a10a-aac983bb9503",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"8Whichdevicedoyouusetoaccesstheonlineshopping?=%{label}<extra></extra>","labels":["Desktop","Smartphone","Smartphone","Smartphone","Smartphone","Smartphone","Tablet","Desktop","Smartphone","Laptop","Laptop","Laptop","Laptop","Laptop","Smartphone","Smartphone","Laptop","Laptop","Laptop","Smartphone","Smartphone","Tablet","Tablet","Desktop","Smartphone","Laptop","Laptop","Laptop","Laptop","Laptop","Smartphone
# ...

# %%
#Most of the customers use only smartphone for online shopping. The next usage is from laptop

# %%
#count of OS of devices
data.value_counts(data['10Whatistheoperatingsystem(OS)ofyourdevice?'])
# Out:
# 10Whatistheoperatingsystem(OS)ofyourdevice?
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# dtype: int64

# %%
plt.figure(figsize = (8,6))
sns.countplot(x ='10Whatistheoperatingsystem(OS)ofyourdevice?', data = data)
plt.title('Type of OS used by customers')
plt.show()

fig = px.pie(data, names='10Whatistheoperatingsystem(OS)ofyourdevice?', title='Type of OS used')
fig.show()
# Out:
# <div>                            <div id="78f9a615-330a-45de-ac7f-93190b953013" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78f9a615-330a-45de-ac7f-93190b953013")) {                    Plotly.newPlot(                        "78f9a615-330a-45de-ac7f-93190b953013",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"10Whatistheoperatingsystem(OS)ofyourdevice?=%{label}<extra></extra>","labels":["Window/windows Mobile","IOS/Mac","Android","IOS/Mac","IOS/Mac","Android","Android","Window/windows Mobile","Android","Window/windows Mobile","Window/windows Mobile","Window/windows Mobile","Window/windows Mobile","Window/windows Mobile","Android","IOS/Mac","IOS/Mac","Window/windows Mobile","Window/windows Mobile","IOS/Mac","IOS/
# ...

# %%
#close to 45% customers use windows OS for shopping. Next highest usage is android OS

# %%
#Analysis of customers using type of browsers for shopping:
plt.figure(figsize = (8,6))
sns.countplot(x ='11Whatbrowserdoyourunonyourdevicetoaccessthewebsite?', data = data)
plt.title('Browsers Used for shopping')
plt.show()
fig = px.pie(data, names='11Whatbrowserdoyourunonyourdevicetoaccessthewebsite?', title='Browsers')
fig.show()
# Out:
# <div>                            <div id="da1a640d-6ed0-4321-b8a1-442c8fcacfec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da1a640d-6ed0-4321-b8a1-442c8fcacfec")) {                    Plotly.newPlot(                        "da1a640d-6ed0-4321-b8a1-442c8fcacfec",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"11Whatbrowserdoyourunonyourdevicetoaccessthewebsite?=%{label}<extra></extra>","labels":["Google chrome","Google chrome","Google chrome","Safari","Safari","Google chrome","Google chrome","Google chrome","Google chrome","Google chrome","Google chrome","Google chrome","Google chrome","Google chrome","Google chrome","Safari","Safari","Google chrome","Google chrome","Safari","Safari","Google chrome","Google chro
# ...

# %%
#Most fastest browser is the most used browser-80%

# %%
#analysis of channels used  to arrive at online store:
fig = px.pie(data, names='12Whichchanneldidyoufollowtoarriveatyourfavoriteonlinestoreforthefirsttime?', title='Channel used ')
fig.show()
# Out:
# <div>                            <div id="5bcea2b9-7f9f-4f23-86a3-e1ddd7d8bf5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bcea2b9-7f9f-4f23-86a3-e1ddd7d8bf5a")) {                    Plotly.newPlot(                        "5bcea2b9-7f9f-4f23-86a3-e1ddd7d8bf5a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"12Whichchanneldidyoufollowtoarriveatyourfavoriteonlinestoreforthefirsttime?=%{label}<extra></extra>","labels":["Search Engine","Search Engine","Search Engine","Search Engine","Content Marketing","Search Engine","Display Adverts","Search Engine","Search Engine","Search Engine","Search Engine","Search Engine","Search Engine","Search Engine","Search Engine","Search Engine","Content Marketing","Search Engine","
# ...

# %%
#Most customers use search engines, i.e.,google chrome for arriving at an online store

# %%
#values of customers reaching online stores for the second time: 
data.value_counts(data['13Afterfirstvisit,howdoyoureachtheonlineretailstore?'])
# Out:
# 13Afterfirstvisit,howdoyoureachtheonlineretailstore?
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# dtype: int64

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='13Afterfirstvisit,howdoyoureachtheonlineretailstore?', data = data)
plt.title('Customers visit after firstime ')
plt.show()
fig = px.pie(data, names='13Afterfirstvisit,howdoyoureachtheonlineretailstore?', title='Channel used to revisit ')
fig.show()
# Out:
# <div>                            <div id="0d5dd3ea-2d85-4ab7-924c-863171501bf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d5dd3ea-2d85-4ab7-924c-863171501bf0")) {                    Plotly.newPlot(                        "0d5dd3ea-2d85-4ab7-924c-863171501bf0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"13Afterfirstvisit,howdoyoureachtheonlineretailstore?=%{label}<extra></extra>","labels":["Search Engine","Via application","Via application","Search Engine","Via application","Via application","Direct URL","E-mail","Direct URL","Search Engine","Direct URL","Direct URL","Direct URL","Search Engine","Via application","Search Engine","Via application","Via application","Direct URL","Search Engine","Via applicat
# ...

# %%
#customers visiting the online store after the first visit is same from seach engine and through applications. Least revisits are form social media.

# %%
#Time spent by customers on online stores before making a purchase: 
plt.figure(figsize = (7,4))
sns.countplot(y ='14Howmuchtimedoyouexplorethee-retailstorebeforemakingapurchasedecision?', data = data)
plt.title('Time spent by customers online')
plt.show()
fig = px.pie(data, names='14Howmuchtimedoyouexplorethee-retailstorebeforemakingapurchasedecision?', title='Time spent ')
fig.show()
# Out:
# <div>                            <div id="87463a63-181f-43af-aa4e-e9cdec85a04a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87463a63-181f-43af-aa4e-e9cdec85a04a")) {                    Plotly.newPlot(                        "87463a63-181f-43af-aa4e-e9cdec85a04a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"14Howmuchtimedoyouexplorethee-retailstorebeforemakingapurchasedecision?=%{label}<extra></extra>","labels":["6-10 mins","more than 15 mins","11-15 mins","6-10 mins","more than 15 mins","more than 15 mins","more than 15 mins","6-10 mins","1-5 mins","more than 15 mins","6-10 mins","more than 15 mins","more than 15 mins","11-15 mins","11-15 mins","6-10 mins","more than 15 mins","more than 15 mins","more than 15
# ...

# %%
#Huge percentage is for customers spending more than 15 minutes on online shopping

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='15WhatisyourpreferredpaymentOption?',palette="Set3", data = data)
plt.title('Analysis of Customer according to Prefered paymet option ')
plt.show()

fig = px.pie(data, names='15WhatisyourpreferredpaymentOption?', title='Payment mode used ')
fig.show()
# Out:
# <div>                            <div id="6056d6ce-94d3-42bf-9e3e-356e31cd94e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6056d6ce-94d3-42bf-9e3e-356e31cd94e8")) {                    Plotly.newPlot(                        "6056d6ce-94d3-42bf-9e3e-356e31cd94e8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"15WhatisyourpreferredpaymentOption?=%{label}<extra></extra>","labels":["E-wallets (Paytm, Freecharge etc.)","Credit/Debit cards","E-wallets (Paytm, Freecharge etc.)","Credit/Debit cards","Credit/Debit cards","E-wallets (Paytm, Freecharge etc.)","Credit/Debit cards","Credit/Debit cards","Cash on delivery (CoD)","Cash on delivery (CoD)","Credit/Debit cards","Credit/Debit cards","Credit/Debit cards","Credit/De
# ...

# %%
#We found that most of customers prefer the Credit/Debit card option for online payment.

# %%
plt.figure(figsize = (8,6))
sns.countplot(x ='16Howfrequentlydoyouabandon(selectinganitemsandleavingwithoutmakingpayment)yourshoppingcart?',hue = '15WhatisyourpreferredpaymentOption?',palette="Set2", data = data)
plt.title('Analysis of Customer according to Product abandoned ')
plt.show()

fig = px.pie(data, names='16Howfrequentlydoyouabandon(selectinganitemsandleavingwithoutmakingpayment)yourshoppingcart?', title=' product Abandon ')
fig.show()
# Out:
# <div>                            <div id="1bd22a5e-b794-4158-a353-186ab40332c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bd22a5e-b794-4158-a353-186ab40332c9")) {                    Plotly.newPlot(                        "1bd22a5e-b794-4158-a353-186ab40332c9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"16Howfrequentlydoyouabandon(selectinganitemsandleavingwithoutmakingpayment)yourshoppingcart?=%{label}<extra></extra>","labels":["Sometimes","Very frequently","Sometimes","Never","Frequently","Frequently","Sometimes","Sometimes","Sometimes","Sometimes","Sometimes","Sometimes","Sometimes","Sometimes","Sometimes","Never","Frequently","Frequently","Sometimes","Never","Frequently","Sometimes","Sometimes","Someti
# ...

# %%
#We can see people using COD have abadoned produects very rarely while custoemrs using onilne payment methods are frequent

#We can see most of the customers abadone the cart because of they get an better alternative offier , also some customers found their promrocode is not applicable for the payment

# %%
17WhydidyouabandontheBag,ShoppingCart?
plt.figure(figsize = (14,6))
sns.countplot(x ='17WhydidyouabandontheBag,ShoppingCart?',palette="Set2", data = data)
plt.title('Analysis of Customer according to Product abandoned ')
plt.show()

fig = px.pie(data, names='17WhydidyouabandontheBag,ShoppingCart?', title='Reason for product Abandon ')
fig.show()
# Out:
# Object `ShoppingCart` not found.
# ...

# %%
#We can see most of the customers abadone the cart because of they get an better alternative offier , also some customers found their promrocode is not applicable for the payment

# %%
plt.figure(figsize = (6,4))
sns.countplot(y ='19Informationonsimilarproducttotheonehighlightedisimportantforproductcomparison',palette="Set2", data = data)
plt.title('Analysis of Customer based on Product Comparision ')
plt.show()

# %%
#Most of the People say that Product comparision should be shown on webstie/App

# %%
fig = px.pie(data, names='20Completeinformationonlistedsellerandproductbeingofferedisimportantforpurchasedecision.', title='Seller Information display ')
fig.show()
# Out:
# <div>                            <div id="5eb8e823-eddd-46d1-b7da-7161b4fab7c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5eb8e823-eddd-46d1-b7da-7161b4fab7c1")) {                    Plotly.newPlot(                        "5eb8e823-eddd-46d1-b7da-7161b4fab7c1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"20Completeinformationonlistedsellerandproductbeingofferedisimportantforpurchasedecision.=%{label}<extra></extra>","labels":["Indifferent (3)","Strongly agree (5)","Agree (4)","Indifferent (3)","Indifferent (3)","Strongly agree (5)","Agree (4)","Dis-agree (2)","Strongly agree (5)","Agree (4)","Agree (4)","Agree (4)","Strongly agree (5)","Strongly disagree (1)","Agree (4)","Indifferent (3)","Indifferent (3)",
# ...

# %%
#Most of the customers(70%) thinks that the complete information about the product helps to make a buying the product

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='23Loadingandprocessingspeed',palette="Set2", data = data)
plt.title('Analysis of Customers regarding Loading and Processing Speed ')
plt.show()

# %%
#Most of Customers agree that loading and Processing speed should be good

# %%
plt.figure(figsize = (8,4))
sns.countplot(x ='31Enjoymentisderivedfromshoppingonline',hue = '1Genderofrespondent',palette="Set2", data = data)
plt.title('Analysis of Customers who Think shopping is enjoyment ')
plt.show()

# %%
#Above plot shows that females finds the online shopping experince enjoyable than the mans

# %%
plt.figure(figsize = (6,4))
sns.countplot(x ='32Shoppingonlineisconvenientandflexible',hue = '1Genderofrespondent', palette="Set2", data = data)
plt.title('Analysis of Customers who Think shopping is enjoyment ')
plt.show()

# %%
#Above plot shows that most of females find the online shopping convinient and flexible

# %%
plt.figure(figsize = (10,6))
sns.countplot(y ='32Shoppingonlineisconvenientandflexible',hue = '2Howoldareyou?', palette="Set2", data = data)
plt.title('Analysis of Customers who Think shopping is enjoyment ')
plt.show()

# %%
#We can see in above plots customers less than 30 years find the online shopping experince more enjoyable

# %%
plt.figure(figsize = (8,6))
sns.countplot(x ='34Gainingaccesstoloyaltyprogramsisabenefitofshoppingonline',palette="Set2", data = data)
plt.title('Analysis of Customers based on payment option preference ')
plt.show()

plt.figure(figsize=(15,5))

data['34Gainingaccesstoloyaltyprogramsisabenefitofshoppingonline'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
#Most of Customers Agree that getting access to loyalty is benifecial

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data['37NetBenefitderivedfromshoppingonlinecanleadtouserssatisfaction'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(data['37NetBenefitderivedfromshoppingonlinecanleadtouserssatisfaction'])
data['37NetBenefitderivedfromshoppingonlinecanleadtouserssatisfaction'].value_counts()
plt.show()

# %%
#Almost 82 % of Customers think tht Benifits derived fromshopping online leads to User satisfaction

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data['38Usersatisfactioncannotexistwithouttrust'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(data['38Usersatisfactioncannotexistwithouttrust'])
data['38Usersatisfactioncannotexistwithouttrust'].value_counts()
plt.show()

# %%
#Almost 90 % of customers agree with that the trust is important factor for satisfied customer

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data['43Shoppingonthewebsitegivesyouthesenseofadventure'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(data['43Shoppingonthewebsitegivesyouthesenseofadventure'])
data['43Shoppingonthewebsitegivesyouthesenseofadventure'].value_counts()
plt.show()

# %%
#Nearly 58% of users thinks that shopping online gives them adventure while 20 % of peoples dont agree with that

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
data['44Shoppingonyourpreferrede-tailerenhancesyoursocialstatus'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(data['43Shoppingonthewebsitegivesyouthesenseofadventure'])
data['44Shoppingonyourpreferrede-tailerenhancesyoursocialstatus'].value_counts()
plt.show()

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='46Shoppingonthewebsitehelpsyoufulfillcertainroles',palette="Set3", data = data)
plt.title('Analysis of Customer based om preferred paymet option ')
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
data['47Gettingvalueformoneyspent'].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(data['47Gettingvalueformoneyspent'])
data['47Gettingvalueformoneyspent'].value_counts()
plt.show()

# %%
#Almost 82 % of Customers this that they are getting value for money spent

# %%
data['Fromthefollowing,tickany(orall)oftheonlineretailersyouhaveshoppedfrom;'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: Fromthefollowing,tickany(orall)oftheonlineretailersyouhaveshoppedfrom;, dtype: int64

# %%
#We can see form above value count that almost every customer uses Amazon site and Flipcart is second Popular site , Paytm is third used site

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Fromthefollowing,tickany(orall)oftheonlineretailersyouhaveshoppedfrom;',palette="Set2", data = data)
plt.title('Retailers')
plt.show()

fig = px.pie(data, names='Fromthefollowing,tickany(orall)oftheonlineretailersyouhaveshoppedfrom;', title='Retailers ticked ')
fig.show()
# Out:
# <div>                            <div id="8508cb63-b295-46e3-9cfa-6ca6a03f4de5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8508cb63-b295-46e3-9cfa-6ca6a03f4de5")) {                    Plotly.newPlot(                        "8508cb63-b295-46e3-9cfa-6ca6a03f4de5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Fromthefollowing,tickany(orall)oftheonlineretailersyouhaveshoppedfrom;=%{label}<extra></extra>","labels":["Amazon.in, Paytm.com","Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com","Amazon.in, Paytm.com, Myntra.com","Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com","Amaz
# ...

# %%
#Most of the Customers have shopped from all ("Amazon","Flipkart","Paytm","Myntra","Snapdeal")

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Visualappealingweb-pagelayout',palette="Set2", data = data)
plt.title('Customer analysis as per Visual appearance of website ')
plt.show()

fig = px.pie(data, names='Visualappealingweb-pagelayout', title='Visual Apperance of website')
fig.show()
# Out:
# <div>                            <div id="a2a83306-15cd-49e0-a235-b10970516723" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2a83306-15cd-49e0-a235-b10970516723")) {                    Plotly.newPlot(                        "a2a83306-15cd-49e0-a235-b10970516723",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Visualappealingweb-pagelayout=%{label}<extra></extra>","labels":["Flipkart.com","Amazon.in, Myntra.com","Amazon.in, Paytm.com, Myntra.com","Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com","Myntra.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com","A
# ...

# %%
#Amazon and Flipkart have more attractive Website's Visual appearance than the rest

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Wildvarietyofproductonoffer',palette="Set2", data = data)
plt.title('Analysis of Customer according to verity of product offered ')
plt.show()


fig = px.pie(data, names='Wildvarietyofproductonoffer', title='verity of product offered')
fig.show()
# Out:
# <div>                            <div id="9a16cc28-19a7-4c4a-b156-ae1e1b88a103" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a16cc28-19a7-4c4a-b156-ae1e1b88a103")) {                    Plotly.newPlot(                        "9a16cc28-19a7-4c4a-b156-ae1e1b88a103",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Wildvarietyofproductonoffer=%{label}<extra></extra>","labels":["Flipkart.com","Flipkart.com, Myntra.com","Amazon.in, Myntra.com","Amazon.in, Flipkart.com","Myntra.com","Amazon.in, Flipkart.com, Paytm.com","Amazon.in","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com","Amazon.in,
# ...

# %%
#Most variety of Products are provided by azamon, flipkart and Myntra

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Complete,relevantdescriptioninformationofproducts',palette="Set2", data = data)
plt.title('customer analysis based on Relevent information displayed ')
plt.show()

fig = px.pie(data, names='Complete,relevantdescriptioninformationofproducts', title='Relevent information displayed')
fig.show()
# Out:
# <div>                            <div id="9f3d9476-78a6-4035-a4f3-1ef870c091b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f3d9476-78a6-4035-a4f3-1ef870c091b6")) {                    Plotly.newPlot(                        "9f3d9476-78a6-4035-a4f3-1ef870c091b6",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Complete,relevantdescriptioninformationofproducts=%{label}<extra></extra>","labels":["Snapdeal.com","Amazon.in, Flipkart.com, Myntra.com","Amazon.in, Paytm.com, Myntra.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com, Paytm.com","Flipkart.com, Snapdeal.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com","Ama
# ...

# %%
#most relevant information about the product is provided by amazon and flipkart.

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Fastloadingwebsitespeedofwebsiteandapplication',palette="Set2", data = data)
plt.title('Analysis based on website loading speed ')
plt.show()

fig = px.pie(data, names='Fastloadingwebsitespeedofwebsiteandapplication', title='Speed of website loading')
fig.show()
# Out:
# <div>                            <div id="917d43c0-040f-4358-8d3c-a1cbb6894eac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("917d43c0-040f-4358-8d3c-a1cbb6894eac")) {                    Plotly.newPlot(                        "917d43c0-040f-4358-8d3c-a1cbb6894eac",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Fastloadingwebsitespeedofwebsiteandapplication=%{label}<extra></extra>","labels":["Snapdeal.com","Amazon.in, Flipkart.com, Myntra.com","Amazon.in, Paytm.com","Amazon.in, Flipkart.com, Snapdeal.com","Amazon.in","Amazon.in, Paytm.com","Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com, Paytm.com","Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com"
# ...

# %%
#Fastest loading websites are amazon and paytm

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Quicknesstocompletepurchase',palette="Set3", data = data)
plt.title('Analysis based on Fast Checkout ')
plt.show()

fig = px.pie(data, names='Quicknesstocompletepurchase', title='fast Checkout')
fig.show()
# Out:
# <div>                            <div id="919b920e-5df2-475a-8234-36e1dbf1518a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("919b920e-5df2-475a-8234-36e1dbf1518a")) {                    Plotly.newPlot(                        "919b920e-5df2-475a-8234-36e1dbf1518a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Quicknesstocompletepurchase=%{label}<extra></extra>","labels":["Paytm.com","Amazon.com, Flipkart.com, Myntra.com","Amazon.com, Paytm.com, Myntra.com","Amazon.com, Flipkart.com, Paytm.com","Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal","Paytm.com","Amazon.com, Flipkart.com, Paytm.com","Amazon.com","Flipkart.com, Myntra.com, Snapdeal","Amazon.com, Flipkart.com","Amazon.com, Flipkart.com, Paytm.co
# ...

# %%
#Amazon and flipkart are dominating here also in case of faster checkouts followed by the Paytm

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Availabilityofseveralpaymentoptions',palette="Set3", data = data)
plt.title('Analysis by Payment options Available ')
plt.show()



fig = px.pie(data, names='Availabilityofseveralpaymentoptions', title='Payment options Available')
fig.show()
# Out:
# <div>                            <div id="923e741f-289a-43d6-9b9c-fd81cc2e8ae1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("923e741f-289a-43d6-9b9c-fd81cc2e8ae1")) {                    Plotly.newPlot(                        "923e741f-289a-43d6-9b9c-fd81cc2e8ae1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Availabilityofseveralpaymentoptions=%{label}<extra></extra>","labels":["Patym.com","Amazon.in, Flipkart.com, Myntra.com","Patym.com, Myntra.com","Amazon.in, Flipkart.com, Myntra.com","Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com, Snapdeal.com","Amazon.in, Flipkart.com","Flipkart.com, Myntra.com, Snapdeal
# ...

# %%
#We can see in above plot Amazon and Flipcart have more Payment options Avaialable followed by Myntra

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Speedyorderdelivery',palette="Set3", data = data)
plt.title('Analysis based on delivery time ')
plt.show()

fig = px.pie(data, names='Speedyorderdelivery', title='Speed of delivery')
fig.show()
# Out:
# <div>                            <div id="5d6110e1-3c51-4530-8666-c3c3c5a915af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d6110e1-3c51-4530-8666-c3c3c5a915af")) {                    Plotly.newPlot(                        "5d6110e1-3c51-4530-8666-c3c3c5a915af",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Speedyorderdelivery=%{label}<extra></extra>","labels":["Amazon.in","Amazon.in, Flipkart.com","Amazon.in","Amazon.in, Flipkart.com, Snapdeal.com","Amazon.in","Amazon.in","Amazon.in, Flipkart.com, Snapdeal.com","Amazon.in","Flipkart.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com, Myntra.com","Amazon.in, Flipkart.com","Amazo
# ...

# %%
# Amazon and Flipkart are most fast delivery retail stores

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Privacyofcustomersinformation',palette="Set1", data = data)
plt.title('Analysis based on Customer Privacy ')
plt.show()

fig = px.pie(data, names='Privacyofcustomersinformation', title='Customer Privacy')
fig.show()
# Out:
# <div>                            <div id="e27d0b33-68e4-4cc8-adfd-f6f5524fce95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e27d0b33-68e4-4cc8-adfd-f6f5524fce95")) {                    Plotly.newPlot(                        "e27d0b33-68e4-4cc8-adfd-f6f5524fce95",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Privacyofcustomersinformation=%{label}<extra></extra>","labels":["Amazon.in","Myntra.com","Amazon.in","Amazon.in, Flipkart.com, Myntra.com","Amazon.in, Paytm.com","Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com","Paytm.com","Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com, Paytm
# ...

# %%
#Amazon and Flipkart have best policies in maintaining customer's Privacy

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Longerdeliveryperiod',palette="Set3", data = data)
plt.title('Analysis according to Delivery Period ')
plt.show()
fig = px.pie(data, names='Longerdeliveryperiod', title='Delivery Period')
fig.show()
# Out:
# <div>                            <div id="a5072168-3daf-4b23-9def-d72d54d04259" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5072168-3daf-4b23-9def-d72d54d04259")) {                    Plotly.newPlot(                        "a5072168-3daf-4b23-9def-d72d54d04259",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Longerdeliveryperiod=%{label}<extra></extra>","labels":["Paytm.com","Snapdeal.com","Paytm.com","Paytm.com","Paytm.com","Flipkart.com","Snapdeal.com","Flipkart.com","Amazon.in","Snapdeal.com","Paytm.com, Snapdeal.com","Myntra.com","Paytm.com, Snapdeal.com","Snapdeal.com","Paytm.com","Paytm.com","Paytm.com","Flipkart.com","Snapdeal.com","Paytm.com","Paytm.com","Flipkart.com","Amazon.in","Snapdeal.com","Paytm.
# ...

# %%
#Above plot shows that Snapdeal and Paytm has longer delivery Periods and Myntra and Amazon are having least delivery periods

# %%
plt.figure(figsize = (8,6))
sns.countplot(y ='Changeinwebsite/Applicationdesign',palette="Set3", data = data)
plt.title('Analysis based on Dynamic Design of website ')
plt.show()

fig = px.pie(data, names='Changeinwebsite/Applicationdesign', title='Dynamic Design of website')
fig.show()
# Out:
# <div>                            <div id="305cee21-0606-409d-8e42-d4922db83266" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("305cee21-0606-409d-8e42-d4922db83266")) {                    Plotly.newPlot(                        "305cee21-0606-409d-8e42-d4922db83266",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Changeinwebsite/Applicationdesign=%{label}<extra></extra>","labels":["Flipkart.com","Amazon.in","Paytm.com","Amazon.in, Flipkart.com","Amazon.in","Paytm.com","Myntra.com","Amazon.in","Amazon.in","Myntra.com","Amazon.in","Paytm.com","Amazon.in, Flipkart.com","Paytm.com","Paytm.com","Amazon.in, Flipkart.com","Amazon.in","Paytm.com","Myntra.com","Amazon.in, Flipkart.com","Amazon.in","Amazon.in","Amazon.in","My
# ...

# %%
#Above Plot shows that Amazon and Myntra are more dynamic websites

# %%
plt.figure(figsize = (10,8))
sns.countplot(y ='WhichoftheIndianonlineretailerwouldyourecommendtoafriend?',palette="Set3", data = data)
plt.title('Analysis on Customer Satisfaction ')
plt.show()
fig = px.pie(data, names='WhichoftheIndianonlineretailerwouldyourecommendtoafriend?', title='Which online retailer will you recommend to your friends')
fig.show()
# Out:
# <div>                            <div id="d2edbe3c-b9fc-4038-b3af-0404be8d4f1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2edbe3c-b9fc-4038-b3af-0404be8d4f1f")) {                    Plotly.newPlot(                        "d2edbe3c-b9fc-4038-b3af-0404be8d4f1f",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"WhichoftheIndianonlineretailerwouldyourecommendtoafriend?=%{label}<extra></extra>","labels":["Flipkart.com","Amazon.in, Myntra.com","Amazon.in, Paytm.com, Myntra.com","Amazon.in, Flipkart.com","Amazon.in, Myntra.com","Amazon.in, Paytm.com","Flipkart.com, Paytm.com, Myntra.com, snapdeal.com","Amazon.in","Amazon.in","Flipkart.com","Amazon.in","Amazon.in, Flipkart.com","Amazon.in, Flipkart.com, Myntra.com","Am
# ...

# %%
#Amazon and Flipkart are most Popular Websites followed by Myntra. Very few people will recommend Snapdeal & Paytm.
